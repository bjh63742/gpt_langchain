# %%
from deepdiff import DeepDiff
import json

json1 = json.loads('{"predOutputDtoList": [{"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 2, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 3, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 4, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 2, "diseaseAge": 44.30887, "diseaseName": "hypertension", "probability": 0.33263424038887024, "probabilityRatio": 0.6308866569601114, "probabilityPercentile": 0.015867531864525275}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 2, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 3, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 4, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 2, "diseaseAge": 46.70162, "diseaseName": "immunity", "probability": 0.4097616672515869, "probabilityRatio": 0.8701621160290691, "probabilityPercentile": 0.07600570146331448}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 2, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 3, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 4, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 2, "diseaseAge": 44.71167, "diseaseName": "kidney", "probability": 0.13076522946357727, "probabilityRatio": 0.6711671500222182, "probabilityPercentile": 0.03576301312482649}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 2, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 3, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 4, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 2, "diseaseAge": 43.7308, "diseaseName": "liver", "probability": 0.15958508849143982, "probabilityRatio": 0.5730797573185518, "probabilityPercentile": 0.015263561816818485}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 2, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 3, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 4, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 2, "diseaseAge": 46.56956, "diseaseName": "urinary", "probability": 0.4859809875488281, "probabilityRatio": 0.8569555903705235, "probabilityPercentile": 0.02967863390237496}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 2, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 3, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 4, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 42.86406, "diseaseName": "lung", "probability": 0.09354260563850404, "probabilityRatio": 0.4864055421029548, "probabilityPercentile": 0.007761752500931085}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 2, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 3, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 4, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 41.38475, "diseaseName": "pancreatic", "probability": 0.050980061292648315, "probabilityRatio": 0.3384745728396824, "probabilityPercentile": 0.0002641223955385241}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "bpHigh", "valueCurrent": 103, "changeRiskRatio": 0.8303365111351013, "valueSampleGroup": 124.04608917236328, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 2, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 3, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 4, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 3, "diseaseAge": 45.90586, "diseaseName": "prostate", "probability": 0.23573198914527893, "probabilityRatio": 0.7905862571554032, "probabilityPercentile": 0.1942844889708079}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 2, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 3, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 4, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 43.83772, "diseaseName": "stomach", "probability": 0.10309094190597534, "probabilityRatio": 0.5837724855947165, "probabilityPercentile": 0.007404350192885656}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "bpHigh", "valueCurrent": 103, "changeRiskRatio": 0.8303365111351013, "valueSampleGroup": 124.04608917236328, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 2, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 3, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 4, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 41.66703, "diseaseName": "colorectal", "probability": 0.08693933486938477, "probabilityRatio": 0.366702955251461, "probabilityPercentile": 0.0000192209254396003}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 2, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 3, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 4, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 40.60425, "diseaseName": "cvd", "probability": 0.08552825450897217, "probabilityRatio": 0.2604252893851929, "probabilityPercentile": 0.0000051826180289538115}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 2, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 3, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 4, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 40.52924, "diseaseName": "stroke", "probability": 0.06852015852928162, "probabilityRatio": 0.2529243069850585, "probabilityPercentile": 0.0001444567585275891}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "bpHigh", "valueCurrent": 103, "changeRiskRatio": 0.8303365111351013, "valueSampleGroup": 124.04608917236328, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 2, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 3, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 4, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 40.23473, "diseaseName": "dementia", "probability": 0.043918073177337646, "probabilityRatio": 0.22347321409902485, "probabilityPercentile": 0.00010177968804114812}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 2, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 3, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 4, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 41.56573, "diseaseName": "dm", "probability": 0.14853304624557495, "probabilityRatio": 0.35657289996528796, "probabilityPercentile": 0.013774813918085991}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "bpHigh", "valueCurrent": 103, "changeRiskRatio": 0.8303365111351013, "valueSampleGroup": 124.04608917236328, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 2, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 3, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 4, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 40.09281, "diseaseName": "fracture", "probability": 0.03087174892425537, "probabilityRatio": 0.209281390074238, "probabilityPercentile": 0.004238562161076209}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 2, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 3, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 4, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 40.41628, "diseaseName": "hyperlipidemia", "probability": 0.13783344626426697, "probabilityRatio": 0.24162814178942835, "probabilityPercentile": 0.0000006342640757051043}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 2, "factorName": "hmg", "valueCurrent": 16.100000381469727, "changeRiskRatio": 1.075459599494934, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 3, "factorName": "waist", "valueCurrent": 87, "changeRiskRatio": 1.0335805416107178, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 4, "factorName": "bpLwst", "valueCurrent": 71, "changeRiskRatio": 0.9043561220169068, "valueSampleGroup": 78.50889587402344, "isItValueNormalRange": true}, {"rank": 5, "factorName": "blds", "valueCurrent": 83, "changeRiskRatio": 0.8491907119750977, "valueSampleGroup": 97.7401123046875, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "exercising", "valueCurrent": 1, "changeRiskRatio": 0.5, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 2, "factorName": "drinking", "valueCurrent": 2, "changeRiskRatio": 1, "valueSampleGroup": 2, "isItValueNormalRange": false}, {"rank": 3, "factorName": "sgptAlt", "valueCurrent": 46, "changeRiskRatio": 1.60254967212677, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 4, "factorName": "bmi", "valueCurrent": 24, "changeRiskRatio": 0.9940252900123596, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyHprtsPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}, {"rank": 2, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 39.67512, "diseaseName": "thyroid", "probability": 0.03145727515220642, "probabilityRatio": 0.16751208659507513, "probabilityPercentile": 0.0017123077309351695}], "healthAnalysisHealthAge": 43}')
json2 = json.loads('{"predOutputDtoList": [{"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 2, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}, {"rank": 3, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 4, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 5, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 37.5508, "diseaseName": "hypertension", "probability": 0.13449043035507202, "probabilityRatio": 0.2550796271022646, "probabilityPercentile": 0.000007307520229427045}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "totChole", "valueCurrent": 288, "changeRiskRatio": 1.4694747924804688, "valueSampleGroup": 195.98838806152344, "isItValueNormalRange": false}, {"rank": 2, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 3, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}, {"rank": 4, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 5, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 41.07195, "diseaseName": "immunity", "probability": 0.28592967987060547, "probabilityRatio": 0.6071948529020361, "probabilityPercentile": 0.000007331109699360017}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "totChole", "valueCurrent": 288, "changeRiskRatio": 1.4694747924804688, "valueSampleGroup": 195.98838806152344, "isItValueNormalRange": false}, {"rank": 2, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 3, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 4, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 5, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 38.05365, "diseaseName": "kidney", "probability": 0.059495121240615845, "probabilityRatio": 0.3053653568849716, "probabilityPercentile": 0.00007037414524868613}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 2, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}, {"rank": 3, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 4, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 5, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 2, "diseaseAge": 40.95599, "diseaseName": "liver", "probability": 0.16585606336593628, "probabilityRatio": 0.5955992094377887, "probabilityPercentile": 0.02022724965846162}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 2, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 3, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 4, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}, {"rank": 5, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 40.73076, "diseaseName": "urinary", "probability": 0.32499241828918457, "probabilityRatio": 0.573076060208981, "probabilityPercentile": 0.00000000914245062988428}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "totChole", "valueCurrent": 288, "changeRiskRatio": 1.4694747924804688, "valueSampleGroup": 195.98838806152344, "isItValueNormalRange": false}, {"rank": 2, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 3, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 4, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 5, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 38.89136, "diseaseName": "lung", "probability": 0.07483631372451782, "probabilityRatio": 0.38913602521221174, "probabilityPercentile": 0.0019995062898067184}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 2, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}, {"rank": 3, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 4, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 5, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 37.60161, "diseaseName": "pancreatic", "probability": 0.03918471932411194, "probabilityRatio": 0.2601611453335828, "probabilityPercentile": 0.00005302271883828036}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "totChole", "valueCurrent": 288, "changeRiskRatio": 1.4694747924804688, "valueSampleGroup": 195.98838806152344, "isItValueNormalRange": false}, {"rank": 2, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}, {"rank": 3, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 4, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 5, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 36.01345, "diseaseName": "prostate", "probability": 0.03021851181983948, "probabilityRatio": 0.10134534665013098, "probabilityPercentile": 0.0001077935192553836}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "totChole", "valueCurrent": 288, "changeRiskRatio": 1.4694747924804688, "valueSampleGroup": 195.98838806152344, "isItValueNormalRange": false}, {"rank": 2, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 3, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 4, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 5, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 38.63451, "diseaseName": "stomach", "probability": 0.06418335437774658, "probabilityRatio": 0.3634507127995491, "probabilityPercentile": 0.00009688079832537166}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 2, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 3, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 4, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 5, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 39.30423, "diseaseName": "colorectal", "probability": 0.10204634070396423, "probabilityRatio": 0.43042306183916584, "probabilityPercentile": 0.00010676473203974356}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}, {"rank": 2, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 3, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 4, "factorName": "totChole", "valueCurrent": 288, "changeRiskRatio": 1.4694747924804688, "valueSampleGroup": 195.98838806152344, "isItValueNormalRange": false}, {"rank": 5, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 39.98747, "diseaseName": "cvd", "probability": 0.16379746794700625, "probabilityRatio": 0.4987474985378791, "probabilityPercentile": 0.001401696400909869}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 2, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 3, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 4, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 5, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 38.10763, "diseaseName": "stroke", "probability": 0.08418944478034973, "probabilityRatio": 0.31076339333667996, "probabilityPercentile": 0.00041231907281624736}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 2, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 3, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 4, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 5, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 37.41943, "diseaseName": "dementia", "probability": 0.04754781723022461, "probabilityRatio": 0.24194284428020585, "probabilityPercentile": 0.00014380725508394976}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 2, "factorName": "totChole", "valueCurrent": 288, "changeRiskRatio": 1.4694747924804688, "valueSampleGroup": 195.98838806152344, "isItValueNormalRange": false}, {"rank": 3, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 4, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 5, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 3, "diseaseAge": 43.46002, "diseaseName": "dm", "probability": 0.3524083197116852, "probabilityRatio": 0.8460020157651182, "probabilityPercentile": 0.29895103652757815}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "totChole", "valueCurrent": 288, "changeRiskRatio": 1.4694747924804688, "valueSampleGroup": 195.98838806152344, "isItValueNormalRange": false}, {"rank": 2, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}, {"rank": 3, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 4, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 5, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 38.6796, "diseaseName": "fracture", "probability": 0.05427888035774231, "probabilityRatio": 0.3679597019531526, "probabilityPercentile": 0.017681327512497624}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}, {"rank": 2, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 3, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 4, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 5, "factorName": "gammaGtp", "valueCurrent": 93, "changeRiskRatio": 2.105074405670166, "valueSampleGroup": 44.17896270751953, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 5, "diseaseAge": 48.99077, "diseaseName": "hyperlipidemia", "probability": 0.798084020614624, "probabilityRatio": 1.3990766691214969, "probabilityPercentile": 0.9946042199009064}, {"factors": {"normalRanged": {"controllableFactors": [{"rank": 1, "factorName": "waist", "valueCurrent": 89.4000015258789, "changeRiskRatio": 1.0620931386947632, "valueSampleGroup": 84.17340850830078, "isItValueNormalRange": true}, {"rank": 2, "factorName": "creatinine", "valueCurrent": 0.8999999761581421, "changeRiskRatio": 0.8980215191841125, "valueSampleGroup": 1.002203106880188, "isItValueNormalRange": true}, {"rank": 3, "factorName": "hmg", "valueCurrent": 16.200000762939453, "changeRiskRatio": 1.082139492034912, "valueSampleGroup": 14.970344543457031, "isItValueNormalRange": true}, {"rank": 4, "factorName": "exercising", "valueCurrent": 3, "changeRiskRatio": 1.5, "valueSampleGroup": 2, "isItValueNormalRange": true}, {"rank": 5, "factorName": "sgotAst", "valueCurrent": 38, "changeRiskRatio": 1.4266133308410645, "valueSampleGroup": 26.636510848999023, "isItValueNormalRange": true}], "uncontrollableFactors": []}, "abnormalRanged": {"controllableFactors": [{"rank": 1, "factorName": "totChole", "valueCurrent": 288, "changeRiskRatio": 1.4694747924804688, "valueSampleGroup": 195.98838806152344, "isItValueNormalRange": false}, {"rank": 2, "factorName": "sgptAlt", "valueCurrent": 61, "changeRiskRatio": 2.125120162963867, "valueSampleGroup": 28.70425796508789, "isItValueNormalRange": false}, {"rank": 3, "factorName": "smoking", "valueCurrent": 5, "changeRiskRatio": 1.25, "valueSampleGroup": 4, "isItValueNormalRange": false}, {"rank": 4, "factorName": "bmi", "valueCurrent": 27.299999237060547, "changeRiskRatio": 1.130703687667847, "valueSampleGroup": 24.14425468444824, "isItValueNormalRange": false}, {"rank": 5, "factorName": "triglyceride", "valueCurrent": 234, "changeRiskRatio": 1.5000466108322144, "valueSampleGroup": 155.9951629638672, "isItValueNormalRange": false}], "uncontrollableFactors": [{"rank": 1, "factorName": "fmlyDiabmlPatienYn", "valueCurrent": 1, "changeRiskRatio": 0, "valueSampleGroup": 0, "isItValueNormalRange": false}]}}, "riskIndex": 1, "diseaseAge": 36.56604, "diseaseName": "thyroid", "probability": 0.029408812522888184, "probabilityRatio": 0.156603886578105, "probabilityPercentile": 0.0015126417802389658}], "healthAnalysisHealthAge": 41}')

diff = DeepDiff(json1, json2)
print(diff)
# Out:
# {'type_changes': {"root['predOutputDtoList'][0]['factors']['normalRanged']['controllableFactors'][2]['valueCurrent']": {'old_type': <class 'int'>, 'new_type': <class 'float'>, 'old_value': 87, 'new_value': 16.200000762939453}, "root['predOutputDtoList'][0]['factors']['normalRanged']['controllableFactors'][3]['valueSampleGroup']": {'old_type': <class 'float'>, 'new_type': <class 'int'>, 'old_value': 78.50889587402344, 'new_value': 2}, "root['predOutputDtoList'][0]['factors']['abnormalRanged']['controllableFactors'][0]['valueSampleGroup']": {'old_type': <class 'int'>, 'new_type': <class 'float'>, 'old_value': 2, 'new_value': 28.70425796508789}, "root['predOutputDtoList'][0]['factors']['abnormalRanged']['controllableFactors'][1]['changeRiskRatio']": {'old_type': <class 'int'>, 'new_type': <class 'float'>, 'old_value': 1, 'new_value': 2.105074405670166}, "root['predOutputDtoList'][0]['factors']['abnormalRanged']['controllableFactors'][1]['valueSampleGroup']": {'old_type': <class 'int'>, 
# ...
