# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts.few_shot import FewShotPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler
from langchain.prompts.prompt import PromptTemplate

chat = ChatOpenAI(
    temperature=0.1,
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ],
)

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts.few_shot import FewShotPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler
from langchain.prompts.prompt import PromptTemplate

chat = ChatOpenAI(
    temperature=0.1,
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ],
)

examples = [
    {
        "question": "그대들은 어떻게 살 것인가 에 대한 정보를 줘",
        "answer": """
        감독 : 미야자키 하야오
        주요 출연진 : 산토키 소마 , 스다 마사키 , 기무라 타쿠야
        제작비 : 476억원
        흥행 수익 : 1000억원
        영화 장르 : 애니메이션
        시놉시스 : 성장과 상실, 모험을 중심으로 한 애니메이션 영화
        """,
    },
    {
        "question": "센과 치히로의 행방불명 에 대한 정보를 줘",
        "answer": """
        감독 : 미야자키 하야오
        주요 출연진 : 히이라기 루미, 이리노 미유, 나쓰카와 유코
        제작비 : 190억원
        흥행 수익 : 3,500억원
        영화 장르 : 애니메이션, 판타지
        시놉시스 : 신비로운 세계에 갇힌 소녀가 가족을 구하기 위해 성장하는 이야기
        """
    },
    {
        "question": "인터스텔라 에 대한 정보를 줘",
        "answer": """
        감독 : 크리스토퍼 놀란
        주요 출연진 : 매튜 맥커너히, 앤 해서웨이, 제시카 차스테인
        제작비 : 1,800억원
        흥행 수익 : 9,000억원
        영화 장르 : SF, 드라마
        시놉시스 : 인류의 생존을 위해 우주로 떠난 탐사팀이 차원의 벽을 넘어 미지의 세계를 탐험하는 이야기
        """
    },
    {
        "question": "기생충 에 대한 정보를 줘",
        "answer": """
        감독 : 봉준호
        주요 출연진 : 송강호, 이선균, 조여정
        제작비 : 135억원
        흥행 수익 : 3,000억원
        영화 장르 : 드라마, 스릴러
        시놉시스 : 가난한 가족이 부잣집에 접근하며 벌어지는 예측 불가능한 사건들
        """
    },
]

example_prompt = PromptTemplate.from_template("Human: {question}\nAI:{answer}")
prompt = FewShotPromptTemplate(
    example_prompt=example_prompt,
    examples=examples,
    suffix="Human:{movie}에 대한 정보를 알려줘.\nAI:",
    input_variables=["movie"],
)

movieChain = prompt | chat

movieChain.invoke({
    "movie": "설국열차"
})
# Out:
#         감독 : 봉준호
#         주요 출연진 : 크리스 에반스, 송강호, 에드 해리스
#         제작비 : 400억원
#         흥행 수익 : 1,500억원
#         영화 장르 : SF, 액션, 드라마
#         시놉시스 : 세계가 얼어붙은 지구에서 생존을 위해 움직이는 열차 안에서 벌어지는 이야기
# AIMessageChunk(content='        감독 : 봉준호\n        주요 출연진 : 크리스 에반스, 송강호, 에드 해리스\n        제작비 : 400억원\n        흥행 수익 : 1,500억원\n        영화 장르 : SF, 액션, 드라마\n        시놉시스 : 세계가 얼어붙은 지구에서 생존을 위해 움직이는 열차 안에서 벌어지는 이야기')

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts.few_shot import FewShotChatMessagePromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler
from langchain.prompts import ChatPromptTemplate, ChatPromptTemplate

chat = ChatOpenAI(
    temperature=0.1,
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ],
)

examples = [
    {
        "question": "그대들은 어떻게 살 것인가",
        "answer": """
        감독 : 미야자키 하야오
        주요 출연진 : 산토키 소마 , 스다 마사키 , 기무라 타쿠야
        제작비 : 476억원
        흥행 수익 : 1000억원
        영화 장르 : 애니메이션
        시놉시스 : 성장과 상실, 모험을 중심으로 한 애니메이션 영화
        """,
    },
    {
        "question": "센과 치히로의 행방불명",
        "answer": """
        감독 : 미야자키 하야오
        주요 출연진 : 히이라기 루미, 이리노 미유, 나쓰카와 유코
        제작비 : 190억원
        흥행 수익 : 3,500억원
        영화 장르 : 애니메이션, 판타지
        시놉시스 : 신비로운 세계에 갇힌 소녀가 가족을 구하기 위해 성장하는 이야기
        """
    },
    {
        "question": "인터스텔라",
        "answer": """
        감독 : 크리스토퍼 놀란
        주요 출연진 : 매튜 맥커너히, 앤 해서웨이, 제시카 차스테인
        제작비 : 1,800억원
        흥행 수익 : 9,000억원
        영화 장르 : SF, 드라마
        시놉시스 : 인류의 생존을 위해 우주로 떠난 탐사팀이 차원의 벽을 넘어 미지의 세계를 탐험하는 이야기
        """
    },
    {
        "question": "기생충",
        "answer": """
        감독 : 봉준호
        주요 출연진 : 송강호, 이선균, 조여정
        제작비 : 135억원
        흥행 수익 : 3,000억원
        영화 장르 : 드라마, 스릴러
        시놉시스 : 가난한 가족이 부잣집에 접근하며 벌어지는 예측 불가능한 사건들
        """
    },
]

example_prompt = ChatPromptTemplate.from_messages(
    [
        ("human", "{question} 에 대한 정보를 줘"),
        ("ai", "{answer}"),
    ]
)

example_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=example_prompt,
    examples=examples,
)

final_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "너는 영화 전문가겸 평점을 매기는 인공지능이야."),
        example_prompt,
        ("human", "{movie} 에 대한 정보를 줘, 그리고 평점도 매겨줘 "),
    ]
)

movieChain = final_prompt | chat

movieChain.invoke({
    "movie": "설국열차"
})
# Out:
#         영화 정보:
#         - 감독: 봉준호
#         - 주요 출연진: 크리스 에반스, 송강호, 에드 해리스
#         - 제작비: 약 400억원
#         - 흥행 수익: 약 1,500억원
#         - 영화 장르: SF, 액션, 드라마
#
#         평점:
#         - 이 영화에 대한 평가는 개인마다 다를 수 있지만, 전반적으로 관객과 비평가들로부터 높은 평가를 받았습니다.
#         - 제가 매기는 평점은 9점으로, 훌륭한 연출과 스토리, 배우들의 연기로 인해 극적인 분위기를 만들어내는데 성공했다고 생각합니다.
# AIMessageChunk(content='\n        영화 정보:\n        - 감독: 봉준호\n        - 주요 출연진: 크리스 에반스, 송강호, 에드 해리스\n        - 제작비: 약 400억원\n        - 흥행 수익: 약 1,500억원\n        - 영화 장르: SF, 액션, 드라마\n\n        평점:\n        - 이 영화에 대한 평가는 개인마다 다를 수 있지만, 전반적으로 관객과 비평가들로부터 높은 평가를 받았습니다.\n        - 제가 매기는 평점은 9점으로, 훌륭한 연출과 스토리, 배우들의 연기로 인해 극적인 분위기를 만들어내는데 성공했다고 생각합니다.')
